# %%
import os
import glob

import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 300



directory = "grid4x4"

all_files = glob.glob(os.path.join(directory, '**', '*.csv'), recursive=True)
csv_files = [f for f in all_files if 'queue' not in os.path.basename(f)]

# %%
csv_files.sort()
csv_files = [filename.replace("\\", "/") for filename in csv_files]

# %%
import pandas as pd

experiments = {}
experiments['colight'] = {}
experiments['dqn'] = {}
experiments['mplight'] = {}
experiments['fixedtime'] = {}
experiments['maxpressure'] = {}

for filename in csv_files:
    model_name = filename.split("/")[1]
    experiment_name = filename.split("/")[-1].rstrip(".csv")
    dqn_df = pd.read_csv(filename)
    experiments[model_name][experiment_name] = dqn_df

# %%
import matplotlib.pyplot as plt

dqn_df = experiments['dqn']['train_robust_morning_6']
colight_df = experiments['colight']['train_robust_morning_6']
mplight_df = experiments['mplight']['train_robust_morning_6']


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=3)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=2.5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=1.5)
plt.title(f'Training Model', fontweight='bold', fontsize=20)
plt.xlabel("Episodes", fontsize=16)
plt.ylabel('Travel Time', fontsize=16)
plt.legend(fontsize=12)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,201,25), fontsize=12)
plt.yticks(fontsize=12)
plt.gca().set_facecolor('whitesmoke')

plt.show()

# %%
case_name = 'robust_morning_1'
case_title = 'Case 1'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case1.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_morning_2'
case_title = 'Case 2'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case2.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_morning_3'
case_title = 'Case 3'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case3.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_morning_4'
case_title = 'Case 4'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case4.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_morning_5'
case_title = 'Case 5'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case5.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_evening_1'
case_title = 'Case 6'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case6.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_pse_1'
case_title = 'Case 7'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime'][case_name]
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case7.png', bbox_inches='tight')
plt.show()

# %%
case_name = 'robust_sensor'
case_title = 'Case 8'

dqn_df = experiments['dqn'][case_name]
colight_df = experiments['colight'][case_name]
mplight_df = experiments['mplight'][case_name]
fixedtime_df = experiments['fixedtime']['robust_morning_1']
max_df = experiments['maxpressure'][case_name]


plt.figure(figsize=(8, 6))
plt.plot(dqn_df['episode'], dqn_df['travel_time'], label='dqn', color='blue', linestyle='-', linewidth=6)
plt.plot(colight_df['episode'], colight_df['travel_time'], label='colight', color='red', linestyle='--', linewidth=5)
plt.plot(mplight_df['episode'], mplight_df['travel_time'], label='mplight', color='green', linestyle='-', linewidth=3)
plt.axhline(y=float(max_df['travel_time'].iloc[0]), label='maxpressure', color='coral', linestyle=':', linewidth=7)
plt.axhline(y=float(fixedtime_df['travel_time'].iloc[0]), label='fixedtime', color='purple', linestyle='-.', linewidth=5)
plt.title(case_title, fontweight='bold', fontsize=36)
plt.xlabel("Episodes", fontsize=32)
plt.ylabel('Travel Time (s)', fontsize=32)
plt.legend(loc='upper right', fontsize=20)
plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.xticks(range(0,21,2), fontsize=24)
plt.yticks(fontsize=24)
plt.gca().set_facecolor('whitesmoke')

plt.savefig('case\grid4x4\case8.png', bbox_inches='tight')
plt.show()
